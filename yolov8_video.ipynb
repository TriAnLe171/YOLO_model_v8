# %%
from ultralytics import YOLO

model = YOLO('yolov8x.pt')
results = model('random images for prediction/Shibuya night walk.mp4',device='mps', save=True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/844) /Users/tdle26/Documents/YOLO_model_v8/random images for prediction/Shibuya night walk.mp4: 640x384 11 persons, 1 backpack, 3 handbags, 424.7ms
# video 1/1 (2/844) /Users/tdle26/Documents/YOLO_model_v8/random images for prediction/Shibuya night walk.mp4: 640x384 11 persons, 1 backpack, 3 handbags, 75.4ms
# ...
